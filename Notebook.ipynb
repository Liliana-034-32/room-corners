# %%
import pandas as pd
from plot_drawer import PlotDrawer

json_file = "file.json"
data_frame = pd.read_json(json_file)

drawer = PlotDrawer()

paths = drawer.draw_plots(data_frame)
print("Plots saved at:", paths)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 12>()
#       9 drawer = PlotDrawer()
#      11 # Call the draw_plots function and visualize the plots
# ---> 12 paths = drawer.draw_plots(data_frame)
#      13 print("Plots saved at:", paths)
#
# File c:\Users\Лилюк\PycharmProjects\Project_tech\plot_drawer.py:8, in PlotDrawer.draw_plots(self, json_file)
#       7 def draw_plots(self, json_file):
# ----> 8     data_frame = pd.read_json(json_file)
#      10     # Your plotting logic here
#      11
#      12     # Save plots to the "plots" folder
#      13     os.makedirs("plots", exist_ok=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# ...
